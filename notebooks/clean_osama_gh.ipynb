# %%
import pandas as pd

# %%
df = pd.read_csv("../raw_data/93182_steam_games.csv")
# Out:
# /tmp/ipykernel_16118/581505101.py:1: DtypeWarning: Columns (3,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../raw_data/93182_steam_games.csv")

# %%
df.head()
# Out:
#      AppID                   Name  Release date Estimated owners  Peak CCU  \
# 0  1424640                     余烬   Oct 3, 2020    20000 - 50000         0
# 1   402890            Nyctophilia  Sep 23, 2015   50000 - 100000         0
# 2  1151740        Prison Princess   Apr 2, 2020        0 - 20000         0
# 3   875530           Dead In Time  Oct 12, 2018        0 - 20000         0
# 4  1835360  Panacle: Back To Wild  Mar 11, 2022        0 - 20000         2
#
#    Required age  Price  DLC count  \
# 0             0   3.99          0
# 1             0   0.00          0
# 2             0  19.99          0
# 3             0   7.99          0
# 4             0   3.99          0
#
#                                       About the game  \
# 0  'Ashes of war' is an anti war theme adventure ...
# 1  NYCTOPHILIA Nyctophilia is an 2D psychological...
# 2  ABOUT Now nothing more than a phantom, can the...
# 3  Is a hardcore action with a non-trivial level ...
# ...

# %%
df["Average playtime forever"].value_counts()
# Out:
# 0    93182
# Name: Average playtime forever, dtype: int64

# %%
df.isnull().sum().to_json()
# Out:
# '{"AppID":0,"Name":3,"Release date":0,"Estimated owners":76720,"Peak CCU":0,"Required age":0,"Price":0,"DLC count":0,"About the game":4790,"Supported languages":0,"Full audio languages":0,"Reviews":82583,"Header image":0,"Website":51528,"Support url":48947,"Support email":15832,"Windows":0,"Mac":0,"Linux":0,"Metacritic score":0,"Metacritic url":89159,"User score":0,"Positive":0,"Negative":0,"Score rank":93175,"Achievements":0,"Recommendations":0,"Notes":77842,"Average playtime forever":0,"Average playtime two weeks":0,"Median playtime forever":0,"Median playtime two weeks":0,"Developers":4831,"Publishers":5269,"Categories":5295,"Genres":4801,"Tags":80264,"Screenshots":2813,"Movies":7647}'

# %%
df['Metacritic score'].value_counts()
# Out:
# 0     89159
# 80      210
# 81      183
# 76      181
# 77      179
#       ...
# 33        1
# 23        1
# 20        1
# 97        1
# 24        1
# Name: Metacritic score, Length: 72, dtype: int64

# %%
con = df['Metacritic score'] != 0

# %%
df_filterd_93182_steam_df = df.loc[con, ['Name','Metacritic score']]
df_filterd_93182_steam_df
# Out:
#                                Name  Metacritic score
# 8                     Shadow Empire                78
# 46     SENRAN KAGURA SHINOVI VERSUS                70
# 57                        SpaceChem                84
# 80                       Tannenberg                69
# 115              Total Annihilation                86
# ...                             ...               ...
# 93109             Panzer Tactics HD                69
# 93119             Legend of Dungeon                62
# 93122            Volgarr the Viking                76
# 93142            TrackMania² Canyon                81
# 93162               Bahnsen Knights                78
#
# [4023 rows x 2 columns]

# %%
df1= pd.read_csv("../raw_data/gamesfeatures.csv")

# %%
df1.columns
# Out:
# Index(['QueryID', 'ResponseID', 'QueryName', 'ResponseName', 'ReleaseDate',
#        'RequiredAge', 'DemoCount', 'DeveloperCount', 'DLCCount', 'Metacritic',
#        'MovieCount', 'Unnamed: 11', 'RecommendationCount', 'PublisherCount',
#        'ScreenshotCount', 'SteamSpyOwners', 'SteamSpyOwnersVariance',
#        'SteamSpyPlayersEstimate', 'SteamSpyPlayersVariance',
#        'AchievementCount', 'Unnamed: 20', 'Unnamed: 21', 'IsFree',
#        'Unnamed: 23', 'PurchaseAvail', 'Unnamed: 25', 'PlatformWindows',
#        'PlatformLinux', 'PlatformMac', 'PCReqsHaveMin', 'PCReqsHaveRec',
#        'LinuxReqsHaveMin', 'LinuxReqsHaveRec', 'MacReqsHaveMin',
#        'MacReqsHaveRec', 'CategorySinglePlayer', 'CategoryMultiplayer',
#        'CategoryCoop', 'CategoryMMO', 'CategoryInAppPurchase',
#        'CategoryIncludeSrcSDK', 'CategoryIncludeLevelEditor',
#        'CategoryVRSupport', 'GenreIsNonGame', 'GenreIsIndie', 'GenreIsAction',
# ...

# %%
con2 = df1['Metacritic'] != 0

# %%
df_filterd_gamesfeatures_df = df1.loc[con2, ['QueryName','Metacritic']]
df_filterd_gamesfeatures_df.rename(columns={'QueryName': 'Name'}, inplace=True)

# %%
metacritic_df  = pd.merge(df_filterd_gamesfeatures_df,df_filterd_93182_steam_df,how="outer", on='Name')

# %%
metacritic_df
# Out:
#                                         Name  Metacritic  Metacritic score
# 0                             Counter-Strike        88.0              88.0
# 1                              Day of Defeat        79.0              79.0
# 2                                  Half-Life        96.0              96.0
# 3             Counter-Strike: Condition Zero        65.0              65.0
# 4             Counter-Strike: Condition Zero        65.0              65.0
# ...                                      ...         ...               ...
# 4814                                  ARCADE         NaN              78.0
# 4815  Age of Empires III: Definitive Edition         NaN              75.0
# 4816                               Bombshell         NaN              43.0
# 4817                                 Turmoil         NaN              73.0
# 4818                         Bahnsen Knights         NaN              78.0
#
# [4819 rows x 3 columns]

# %%
metacritic_df['Metacritic'].fillna(metacritic_df['Metacritic score'], inplace=True)
metacritic_df = metacritic_df.drop(columns='Metacritic score')

# %%
metacritic_df = metacritic_df.drop_duplicates()

# %%
metacritic_df.to_csv('../data/metacritic_df.csv')

# %%
df5 = pd.read_csv('../raw_data/gamesfeatures.csv')

# %%
df5.columns
# Out:
# Index(['QueryID', 'ResponseID', 'QueryName', 'ResponseName', 'ReleaseDate',
#        'RequiredAge', 'DemoCount', 'DeveloperCount', 'DLCCount', 'Metacritic',
#        'MovieCount', 'Unnamed: 11', 'RecommendationCount', 'PublisherCount',
#        'ScreenshotCount', 'SteamSpyOwners', 'SteamSpyOwnersVariance',
#        'SteamSpyPlayersEstimate', 'SteamSpyPlayersVariance',
#        'AchievementCount', 'Unnamed: 20', 'Unnamed: 21', 'IsFree',
#        'Unnamed: 23', 'PurchaseAvail', 'Unnamed: 25', 'PlatformWindows',
#        'PlatformLinux', 'PlatformMac', 'PCReqsHaveMin', 'PCReqsHaveRec',
#        'LinuxReqsHaveMin', 'LinuxReqsHaveRec', 'MacReqsHaveMin',
#        'MacReqsHaveRec', 'CategorySinglePlayer', 'CategoryMultiplayer',
#        'CategoryCoop', 'CategoryMMO', 'CategoryInAppPurchase',
#        'CategoryIncludeSrcSDK', 'CategoryIncludeLevelEditor',
#        'CategoryVRSupport', 'GenreIsNonGame', 'GenreIsIndie', 'GenreIsAction',
# ...

# %%
df1.columns
# Out:
# Index(['QueryID', 'ResponseID', 'QueryName', 'ResponseName', 'ReleaseDate',
#        'RequiredAge', 'DemoCount', 'DeveloperCount', 'DLCCount', 'Metacritic',
#        'MovieCount', 'Unnamed: 11', 'RecommendationCount', 'PublisherCount',
#        'ScreenshotCount', 'SteamSpyOwners', 'SteamSpyOwnersVariance',
#        'SteamSpyPlayersEstimate', 'SteamSpyPlayersVariance',
#        'AchievementCount', 'Unnamed: 20', 'Unnamed: 21', 'IsFree',
#        'Unnamed: 23', 'PurchaseAvail', 'Unnamed: 25', 'PlatformWindows',
#        'PlatformLinux', 'PlatformMac', 'PCReqsHaveMin', 'PCReqsHaveRec',
#        'LinuxReqsHaveMin', 'LinuxReqsHaveRec', 'MacReqsHaveMin',
#        'MacReqsHaveRec', 'CategorySinglePlayer', 'CategoryMultiplayer',
#        'CategoryCoop', 'CategoryMMO', 'CategoryInAppPurchase',
#        'CategoryIncludeSrcSDK', 'CategoryIncludeLevelEditor',
#        'CategoryVRSupport', 'GenreIsNonGame', 'GenreIsIndie', 'GenreIsAction',
# ...

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'AppID', 'Name', 'Release date', 'Required age', 'Price',
#        'DLC count', 'Supported languages', 'Windows', 'Mac', 'Linux',
#        'Achievements', 'Recommendations', 'Developers', 'Publishers',
#        'Categories', 'Genres', 'year', 'month', 'day', 'Adventure', 'Casual',
#        'Indie', 'RPG', 'Free To Play', 'Action', 'Strategy', 'Early Access',
#        'Simulation', 'Racing', 'Sports', 'Massively Multiplayer', 'Education',
#        'Game Development', 'Violent', 'Utilities', 'Audio Production', 'Gore',
#        'Design & Illustration', 'Video Production', 'Sexual Content', 'Nudity',
#        'Photo Editing', 'Web Publishing', 'Animation & Modeling',
#        'Software Training', 'Accounting', 'Movie', 'Documentary', 'Episodic',
#        'Short', 'Tutorial', '360 Video'],
#       dtype='object')

# %%
df2= pd.read_csv("../data/93_steam_clean.csv")

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'AppID', 'Name', 'Release date', 'Required age', 'Price',
#        'DLC count', 'Supported languages', 'Windows', 'Mac', 'Linux',
#        'Achievements', 'Recommendations', 'Developers', 'Publishers',
#        'Categories', 'Genres', 'year', 'month', 'day', 'Adventure', 'Casual',
#        'Indie', 'RPG', 'Free To Play', 'Action', 'Strategy', 'Early Access',
#        'Simulation', 'Racing', 'Sports', 'Massively Multiplayer', 'Education',
#        'Game Development', 'Violent', 'Utilities', 'Audio Production', 'Gore',
#        'Design & Illustration', 'Video Production', 'Sexual Content', 'Nudity',
#        'Photo Editing', 'Web Publishing', 'Animation & Modeling',
#        'Software Training', 'Accounting', 'Movie', 'Documentary', 'Episodic',
#        'Short', 'Tutorial', '360 Video'],
#       dtype='object')

# %%
df3 = pd.read_csv("../data/games_may_clean.csv" ,skiprows=[751] )

# %%
df3.head()
# Out:
#    Unnamed: 0   AppID                             name release_date  \
# 0           0     730                 Counter-Strike 2   2012-08-21
# 1           1  578080              PUBG: BATTLEGROUNDS   2017-12-21
# 2           2     570                           Dota 2   2013-07-09
# 3           3  271590               Grand Theft Auto V   2015-04-13
# 4           4  359550  Tom Clancy's Rainbow Six® Siege   2015-12-01
#
#    required_age  price  dlc_count  \
# 0             0   0.00          1
# 1             0   0.00          0
# 2             0   0.00          2
# 3            17   0.00          1
# 4            17  19.99          9
#
#                                       about_the_game  windows    mac  ...  \
# 0  For over two decades, Counter-Strike has offer...     True  False  ...
# 1  LAND, LOOT, SURVIVE! Play PUBG: BATTLEGROUNDS ...     True  False  ...
# 2  The most-played game on Steam. Every day, mill...     True   True  ...
# ...

# %%
df4 = pd.read_csv("../data/steamchart_clean.csv" )

# %%
df4.head()
# Out:
#    Unnamed: 0                          gamename  year      month        avg  \
# 0           0  Counter-Strike: Global Offensive  2021  February   741013.24
# 1           1  Counter-Strike: Global Offensive  2021   January   743209.66
# 2           2  Counter-Strike: Global Offensive  2020  December   717803.75
# 3           3  Counter-Strike: Global Offensive  2020  November   668754.58
# 4           4  Counter-Strike: Global Offensive  2020   October   613666.69
#
#        gain     peak  avg_peak_perc
# 0  -2196.42  1123485       0.659567
# 1  25405.91  1124553       0.660893
# 2  49049.17  1164396       0.616460
# 3  55087.89  1037464       0.644605
# 4   6816.37   943876       0.650156

# %%
gamenames_steamchart = df4['gamename'].value_counts().to_json()
gamenames_games_may = df3['name'].value_counts().to_json()
gamenames_93_steam = df2['Name'].value_counts().to_json()
gamenames_games_features = df1['ResponseName'].value_counts().to_json()

# %%
# task : cleaning the merged dataset for feature selection
# task : create engagment engineered feature using playtime - game achivement - dlc count - RecommendationCount
# task : create engineered feature called pupularity using owners - sales_engineered_feature - Reviews_engineered_feature - Metacritic_Score_engineered_feature - [op] release date - [op] peakccu
# task : budget ranging feature aka 50 - 100 in millions
# task :
